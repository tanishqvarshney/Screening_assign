# %%
search_txt = "placement"
  
replace_txt = "screening"
  

with open(r'example.txt', 'r') as file:
  
    data = file.read()
    data = data.replace(search_txt, replace_txt)

with open(r'example.txt', 'w') as file:
    file.write(data)  
print("placement got replaced by screening")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 6>()
#       1 search_txt = "placement"
#       3 replace_txt = "screening"
# ----> 6 with open(r'example.txt', 'r') as file:
#       8     data = file.read()
#       9     data = data.replace(search_txt, replace_txt)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'
